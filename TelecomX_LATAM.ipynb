# %% [markdown]
# <a href="https://colab.research.google.com/github/REVOLUTTION/TelecomX/blob/main/TelecomX_LATAM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #📌 Extracción

# %%
import pandas as pd

# %%
datos = pd.read_json('/content/TelecomX_Data.json')
datos.head()
# Out:
#    customerID Churn                                           customer  \
# 0  0002-ORFBO    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 1  0003-MKNFE    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 2  0004-TLHLJ   Yes  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 3  0011-IGKFF   Yes  {'gender': 'Male', 'SeniorCitizen': 1, 'Partne...
# 4  0013-EXCHZ   Yes  {'gender': 'Female', 'SeniorCitizen': 1, 'Part...
#
#                                              phone  \
# 0   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 1  {'PhoneService': 'Yes', 'MultipleLines': 'Yes'}
# 2   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 3   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 4   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
#
#                                             internet  \
# 0  {'InternetService': 'DSL', 'OnlineSecurity': '...
# 1  {'InternetService': 'DSL', 'OnlineSecurity': '...
# 2  {'InternetService': 'Fiber optic', 'OnlineSecu...
# ...

# %%
print(datos.info)
# Out:
# <bound method DataFrame.info of       customerID Churn                                           customer  \
# 0     0002-ORFBO    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 1     0003-MKNFE    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 2     0004-TLHLJ   Yes  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 3     0011-IGKFF   Yes  {'gender': 'Male', 'SeniorCitizen': 1, 'Partne...
# 4     0013-EXCHZ   Yes  {'gender': 'Female', 'SeniorCitizen': 1, 'Part...
# ...          ...   ...                                                ...
# 7262  9987-LUTYD    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 7263  9992-RRAMN   Yes  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 7264  9992-UJOEL    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 7265  9993-LHIEB    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 7266  9995-HOTOH    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
#
# ...

# %%
datos.dtypes
# Out:
# customerID    object
# Churn         object
# customer      object
# phone         object
# internet      object
# account       object
# dtype: object

# %% [markdown]
# #🔧 Transformación

# %%
datos = pd.concat([
    datos.drop(['customer', 'phone', 'internet', 'account'], axis=1),
    datos['customer'].apply(pd.Series),
    datos['phone'].apply(pd.Series),
    datos['internet'].apply(pd.Series),
    datos['account'].apply(pd.Series)
], axis=1)
datos
# Out:
#       customerID Churn  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     0002-ORFBO    No  Female              0     Yes        Yes       9
# 1     0003-MKNFE    No    Male              0      No         No       9
# 2     0004-TLHLJ   Yes    Male              0      No         No       4
# 3     0011-IGKFF   Yes    Male              1     Yes         No      13
# 4     0013-EXCHZ   Yes  Female              1     Yes         No       3
# ...          ...   ...     ...            ...     ...        ...     ...
# 7262  9987-LUTYD    No  Female              0      No         No      13
# 7263  9992-RRAMN   Yes    Male              0     Yes         No      22
# 7264  9992-UJOEL    No    Male              0      No         No       2
# 7265  9993-LHIEB    No    Male              0     Yes        Yes      67
# 7266  9995-HOTOH    No    Male              0     Yes        Yes      63
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  \
# ...

# %%
charges_expanded = datos['Charges'].apply(pd.Series)
datos = pd.concat([datos.drop('Charges', axis=1), charges_expanded], axis=1)
datos
# Out:
#       customerID Churn  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     0002-ORFBO    No  Female              0     Yes        Yes       9
# 1     0003-MKNFE    No    Male              0      No         No       9
# 2     0004-TLHLJ   Yes    Male              0      No         No       4
# 3     0011-IGKFF   Yes    Male              1     Yes         No      13
# 4     0013-EXCHZ   Yes  Female              1     Yes         No       3
# ...          ...   ...     ...            ...     ...        ...     ...
# 7262  9987-LUTYD    No  Female              0      No         No      13
# 7263  9992-RRAMN   Yes    Male              0     Yes         No      22
# 7264  9992-UJOEL    No    Male              0      No         No       2
# 7265  9993-LHIEB    No    Male              0     Yes        Yes      67
# 7266  9995-HOTOH    No    Male              0     Yes        Yes      63
#
#      PhoneService     MultipleLines InternetService  ... OnlineBackup  \
# ...

# %%
print(datos.isnull().sum())
# Out:
# customerID          0
# Churn               0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# Monthly             0
# Total               0
# dtype: int64

# %%
print(f"Filas duplicadas: {datos.duplicated().sum()}")
# Out:
# Filas duplicadas: 0

# %%
print(datos.dtypes)
# Out:
# customerID           object
# Churn                object
# gender               object
# SeniorCitizen         int64
# Partner              object
# Dependents           object
# tenure                int64
# PhoneService         object
# MultipleLines        object
# InternetService      object
# OnlineSecurity       object
# OnlineBackup         object
# DeviceProtection     object
# TechSupport          object
# StreamingTV          object
# StreamingMovies      object
# Contract             object
# PaperlessBilling     object
# PaymentMethod        object
# Monthly             float64
# Total                object
# dtype: object

# %%
datos['Total'] = pd.to_numeric(datos['Total'], errors='coerce')
datos.dtypes
# Out:
# customerID           object
# Churn                object
# gender               object
# SeniorCitizen         int64
# Partner              object
# Dependents           object
# tenure                int64
# PhoneService         object
# MultipleLines        object
# InternetService      object
# OnlineSecurity       object
# OnlineBackup         object
# DeviceProtection     object
# TechSupport          object
# StreamingTV          object
# StreamingMovies      object
# Contract             object
# PaperlessBilling     object
# PaymentMethod        object
# Monthly             float64
# Total               float64
# dtype: object

# %%
print(datos.isnull().sum())
# Out:
# customerID           0
# Churn                0
# gender               0
# SeniorCitizen        0
# Partner              0
# Dependents           0
# tenure               0
# PhoneService         0
# MultipleLines        0
# InternetService      0
# OnlineSecurity       0
# OnlineBackup         0
# DeviceProtection     0
# TechSupport          0
# StreamingTV          0
# StreamingMovies      0
# Contract             0
# PaperlessBilling     0
# PaymentMethod        0
# Monthly              0
# Total               11
# dtype: int64

# %%
print(datos[datos['Total'].isnull()])
# Out:
#       customerID Churn  gender  SeniorCitizen Partner Dependents  tenure  \
# 975   1371-DWPAZ    No  Female              0     Yes        Yes       0
# 1775  2520-SGTTA    No  Female              0     Yes        Yes       0
# 1955  2775-SEFEE    No    Male              0      No        Yes       0
# 2075  2923-ARZLG    No    Male              0     Yes        Yes       0
# 2232  3115-CZMZD    No    Male              0      No        Yes       0
# 2308  3213-VVOLG    No    Male              0     Yes        Yes       0
# 2930  4075-WKNIU    No  Female              0     Yes        Yes       0
# 3134  4367-NUYAO    No    Male              0     Yes        Yes       0
# 3203  4472-LVYGI    No  Female              0     Yes        Yes       0
# 4169  5709-LVOEQ    No  Female              0     Yes        Yes       0
# 5599  7644-OMVMY    No    Male              0     Yes        Yes       0
#
#      PhoneService     MultipleLines InternetService  ...         OnlineBackup  \
# ...

# %%
datos['Total'].fillna(0, inplace=True)
# Out:
# /tmp/ipython-input-3675232368.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   datos['Total'].fillna(0, inplace=True)

# %%
print(datos['Total'].isnull().sum())
# Out:
# 0

# %%
datos.columns = datos.columns.str.lower().str.replace(' ', '_')
datos
# Out:
#       customerid churn  gender  seniorcitizen partner dependents  tenure  \
# 0     0002-ORFBO    No  Female              0     Yes        Yes       9
# 1     0003-MKNFE    No    Male              0      No         No       9
# 2     0004-TLHLJ   Yes    Male              0      No         No       4
# 3     0011-IGKFF   Yes    Male              1     Yes         No      13
# 4     0013-EXCHZ   Yes  Female              1     Yes         No       3
# ...          ...   ...     ...            ...     ...        ...     ...
# 7262  9987-LUTYD    No  Female              0      No         No      13
# 7263  9992-RRAMN   Yes    Male              0     Yes         No      22
# 7264  9992-UJOEL    No    Male              0      No         No       2
# 7265  9993-LHIEB    No    Male              0     Yes        Yes      67
# 7266  9995-HOTOH    No    Male              0     Yes        Yes      63
#
#      phoneservice     multiplelines internetservice  ... onlinebackup  \
# ...

# %%
datos.dtypes
# Out:
# customerid           object
# churn                object
# gender               object
# seniorcitizen         int64
# partner              object
# dependents           object
# tenure                int64
# phoneservice         object
# multiplelines        object
# internetservice      object
# onlinesecurity       object
# onlinebackup         object
# deviceprotection     object
# techsupport          object
# streamingtv          object
# streamingmovies      object
# contract             object
# paperlessbilling     object
# paymentmethod        object
# monthly             float64
# total               float64
# dtype: object

# %% [markdown]
# #📊 Carga y análisis

# %%
datos['cuentas_diarias'] = datos['monthly'] / 30
datos.head()
# Out:
#    customerid churn  gender  seniorcitizen partner dependents  tenure  \
# 0  0002-ORFBO    No  Female              0     Yes        Yes       9
# 1  0003-MKNFE    No    Male              0      No         No       9
# 2  0004-TLHLJ   Yes    Male              0      No         No       4
# 3  0011-IGKFF   Yes    Male              1     Yes         No      13
# 4  0013-EXCHZ   Yes  Female              1     Yes         No       3
#
#   phoneservice multiplelines internetservice  ... deviceprotection  \
# 0          Yes            No             DSL  ...               No
# 1          Yes           Yes             DSL  ...               No
# 2          Yes            No     Fiber optic  ...              Yes
# 3          Yes            No     Fiber optic  ...              Yes
# 4          Yes            No     Fiber optic  ...               No
#
#   techsupport streamingtv streamingmovies        contract paperlessbilling  \
# ...

# %%
print(datos[['monthly', 'cuentas_diarias']].head())
# Out:
#    monthly  cuentas_diarias
# 0     65.6         2.186667
# 1     59.9         1.996667
# 2     73.9         2.463333
# 3     98.0         3.266667
# 4     83.9         2.796667

# %%
datos.dtypes
# Out:
# customerid           object
# churn                object
# gender               object
# seniorcitizen         int64
# partner              object
# dependents           object
# tenure                int64
# phoneservice         object
# multiplelines        object
# internetservice      object
# onlinesecurity       object
# onlinebackup         object
# deviceprotection     object
# techsupport          object
# streamingtv          object
# streamingmovies      object
# contract             object
# paperlessbilling     object
# paymentmethod        object
# monthly             float64
# total               float64
# cuentas_diarias     float64
# dtype: object

# %%
# Definir diccionario para mapear texto a números
map_si_no = {
    'yes': 1,
    'no': 0,
    'sí': 1,
    'no': 0
}

# Lista con nombre cambiado a columnas_binarias
columnas_binarias = ['partner', 'dependents', 'phoneservice', 'paperlessbilling', 'churn']

for col in columnas_binarias:
    datos[col] = datos[col].str.lower().map(map_si_no)

# %%
datos.head()
# Out:
#    customerid  churn  gender  seniorcitizen  partner  dependents  tenure  \
# 0  0002-ORFBO    0.0  Female              0        1           1       9
# 1  0003-MKNFE    0.0    Male              0        0           0       9
# 2  0004-TLHLJ    1.0    Male              0        0           0       4
# 3  0011-IGKFF    1.0    Male              1        1           0      13
# 4  0013-EXCHZ    1.0  Female              1        1           0       3
#
#    phoneservice multiplelines internetservice  ... deviceprotection  \
# 0             1            No             DSL  ...               No
# 1             1           Yes             DSL  ...               No
# 2             1            No     Fiber optic  ...              Yes
# 3             1            No     Fiber optic  ...              Yes
# 4             1            No     Fiber optic  ...               No
#
#   techsupport streamingtv streamingmovies        contract paperlessbilling  \
# ...

# %%
datos.rename(columns={
    'customerid': 'id_cliente',
    'gender': 'genero',
    'seniorcitizen': 'adulto_mayor',
    'partner': 'tiene_pareja',
    'dependents': 'tiene_dependientes',
    'tenure': 'meses_contrato',
    'phoneservice': 'servicio_telefono',
    'multiplelines': 'lineas_adicionales',
    'internetservice': 'servicio_internet',
    'onlinesecurity': 'seguridad_online',
    'onlinebackup': 'respaldo_online',
    'deviceprotection': 'proteccion_dispositivos',
    'techsupport': 'soporte_tecnico',
    'streamingtv': 'streaming_tv',
    'streamingmovies': 'streaming_peliculas',
    'contract': 'tipo_contrato',
    'paperlessbilling': 'facturacion_sin_papel',
    'paymentmethod': 'metodo_pago',
    'monthly': 'facturacion_mensual',
    'total': 'facturacion_total',
    'cuentas_diarias': 'facturacion_diaria',
    'churn': 'tasa_abandono'
}, inplace=True)

# %%
datos.head()
# Out:
#    id_cliente  tasa_abandono  genero  adulto_mayor  tiene_pareja  \
# 0  0002-ORFBO            0.0  Female             0             1
# 1  0003-MKNFE            0.0    Male             0             0
# 2  0004-TLHLJ            1.0    Male             0             0
# 3  0011-IGKFF            1.0    Male             1             1
# 4  0013-EXCHZ            1.0  Female             1             1
#
#    tiene_dependientes  meses_contrato  servicio_telefono lineas_adicionales  \
# 0                   1               9                  1                 No
# 1                   0               9                  1                Yes
# 2                   0               4                  1                 No
# 3                   0              13                  1                 No
# 4                   0               3                  1                 No
#
#   servicio_internet  ... proteccion_dispositivos soporte_tecnico streaming_tv  \
# ...

# %% [markdown]
# #📊 Carga y análisis

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Definimos las columnas numéricas que vamos a analizar
numericas = [
    'tasa_abandono', 'adulto_mayor', 'tiene_pareja', 'tiene_dependientes', 'meses_contrato',
    'servicio_telefono', 'facturacion_sin_papel', 'facturacion_mensual', 'facturacion_total', 'facturacion_diaria'
]

# %%
estadisticas = datos[numericas].describe()
medianas = datos[numericas].median()
desviaciones = datos[numericas].std()

# %%
print("=== Estadísticas básicas ===")
print(estadisticas)
print("\n=== Medianas ===")
print(medianas)
print("\n=== Desviaciones estándar ===")
print(desviaciones)
# Out:
# === Estadísticas básicas ===
#        tasa_abandono  adulto_mayor  tiene_pareja  tiene_dependientes  \
# count    7043.000000   7267.000000   7267.000000         7267.000000
# mean        0.265370      0.162653      0.484106            0.300124
# std         0.441561      0.369074      0.499782            0.458343
# min         0.000000      0.000000      0.000000            0.000000
# 25%         0.000000      0.000000      0.000000            0.000000
# 50%         0.000000      0.000000      0.000000            0.000000
# 75%         1.000000      0.000000      1.000000            1.000000
# max         1.000000      1.000000      1.000000            1.000000
#
#        meses_contrato  servicio_telefono  facturacion_sin_papel  \
# count     7267.000000        7267.000000            7267.000000
# mean        32.346498           0.902711               0.593230
# std         24.571773           0.296371               0.491265
# ...

# %% [markdown]
# ##Análisis Descriptivo

# %%
sns.set(style="whitegrid")

# Histogramas para variables numéricas continuas
plt.figure(figsize=(15,10))
for i, col in enumerate(['tasa_abandono', 'meses_contrato', 'facturacion_mensual', 'facturacion_total', 'facturacion_diaria']):
    plt.subplot(2,3,i+1)
    sns.histplot(datos[col], bins=30, kde=True, color='skyblue')
    plt.title(f'Distribución de {col}')
plt.tight_layout()
plt.show()

# %%
#Columnas binarias
binarias = ['adulto_mayor', 'tiene_pareja', 'tiene_dependientes', 'servicio_telefono', 'facturacion_sin_papel']

plt.figure(figsize=(15,7))
for i, col in enumerate(binarias):
    plt.subplot(2,3,i+1)
    sns.countplot(x=col, data=datos, palette='Set2')
    plt.title(f'Conteo de {col}')
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipython-input-3190548209.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=col, data=datos, palette='Set2')
# /tmp/ipython-input-3190548209.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=col, data=datos, palette='Set2')
# /tmp/ipython-input-3190548209.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=col, data=datos, palette='Set2')
# /tmp/ipython-input-3190548209.py:6: FutureWarning:
#
# ...

# %%
plt.figure(figsize=(8,6))
sns.boxplot(x='tasa_abandono', y='facturacion_mensual', data=datos)
plt.title('Facturación mensual según tasa de abandono')
plt.show()

# %% [markdown]
# ##Distribución de evasión

# %%
conteo = datos['tasa_abandono'].value_counts().sort_index()

print("Distribución de tasa_abandono:")
print(conteo)

plt.figure(figsize=(6,6))
colors = ['#2ecc71', '#e74c3c']
plt.pie(conteo.values, labels=['Permanecieron', 'Abandonaron'], autopct='%1.1f%%', colors=colors, startangle=90)
plt.title('Porcentaje de clientes según tasa_abandono')
plt.axis('equal')
plt.show()
# Out:
# Distribución de tasa_abandono:
# tasa_abandono
# 0.0    5174
# 1.0    1869
# Name: count, dtype: int64

# %% [markdown]
# ##Recuento de evasión por variables categóricas

# %%
# Lista de variables categóricas relevantes para explorar
categoricas = ['genero', 'tipo_contrato', 'metodo_pago', 'lineas_adicionales', 'servicio_internet']

# Configuración general de gráficos
sns.set(style="whitegrid")
plt.figure(figsize=(18, 12))

for i, col in enumerate(categoricas, 1):
    plt.subplot(2, 3, i)
    # Calculamos la tasa promedio de abandono por categoría
    tasa_por_categoria = datos.groupby(col)['tasa_abandono'].mean().sort_values(ascending=False)

    # Barplot de tasa promedio de abandono
    sns.barplot(x=tasa_por_categoria.values, y=tasa_por_categoria.index, palette='coolwarm')
    plt.title(f'Tasa promedio de abandono por {col}')
    plt.xlabel('Tasa promedio de abandono')
    plt.ylabel(col)

plt.tight_layout()
plt.show()
# Out:
# /tmp/ipython-input-2057031545.py:14: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=tasa_por_categoria.values, y=tasa_por_categoria.index, palette='coolwarm')
# /tmp/ipython-input-2057031545.py:14: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=tasa_por_categoria.values, y=tasa_por_categoria.index, palette='coolwarm')
# /tmp/ipython-input-2057031545.py:14: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=tasa_por_categoria.values, y=tasa_por_categoria.index, palette='coolwarm')
# ...

# %% [markdown]
# ##Conteo de evasión por variables numéricas

# %%
numericas = ['facturacion_total', 'meses_contrato', 'facturacion_mensual', 'facturacion_diaria']

sns.set(style="whitegrid")
plt.figure(figsize=(16, 10))

for i, col in enumerate(numericas, 1):
    plt.subplot(2, 2, i)
    sns.boxplot(x='tasa_abandono', y=col, data=datos, palette=['#2ecc71', '#e74c3c'])
    plt.title(f'Distribución de {col} según evasión')
    plt.xlabel('Tasa de abandono (0=No, 1=Sí)')
    plt.ylabel(col)

plt.tight_layout()
plt.show()
# Out:
# /tmp/ipython-input-2634609349.py:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='tasa_abandono', y=col, data=datos, palette=['#2ecc71', '#e74c3c'])
# /tmp/ipython-input-2634609349.py:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='tasa_abandono', y=col, data=datos, palette=['#2ecc71', '#e74c3c'])
# /tmp/ipython-input-2634609349.py:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='tasa_abandono', y=col, data=datos, palette=['#2ecc71', '#e74c3c'])
# /tmp/ipython-input-2634609349.py:8: FutureWarning:
#
# ...

# %% [markdown]
# #📄Informe final
